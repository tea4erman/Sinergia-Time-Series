# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
def plot_acf_pacf(y, model_name):
    fig, ax = plt.subplots(1,2, figsize = (8, 4.5))
    plt.suptitle('Эмпирические АКФ и ЧАКФ для модели %s' %model_name)
    sm.graphics.tsa.plot_acf(y, ax = ax[0])
    ax[0].set_xlabel('Лаг')
    ax[0].set_ylabel('Автокорреляция')
    sm.graphics.tsa.plot_pacf(y, ax = ax[1])
    ax[1].set_xlabel('Лаг')
    ax[1].set_ylabel('Частичная автокорреляция')
    plt.tight_layout()
    plt.show()

# %%
sber = pd.read_csv(r'https://raw.githubusercontent.com/tea4erman/Sinergia-Time-Series/refs/heads/main/Data/lesson1_sber.csv', index_col = 0)
sber['TRADEDATE'] = pd.to_datetime(sber['TRADEDATE'])
sber = sber.set_index('TRADEDATE', drop = True)
sber.head()
# Out:
#             CLOSE
# TRADEDATE
# 2013-03-25  98.79
# 2013-03-26  97.20
# 2013-03-27  96.75
# 2013-03-28  98.59
# 2013-03-29  98.76

# %%
plot_acf_pacf(sber.dropna(), 'цен акций Сбербанка')

# %%
adftest = adfuller(sber.dropna(), maxlag = 10, regression = 'c')

dfoutput = pd.Series(
        adftest[0:4],
        index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ]
)

dfoutput
# Out:
# Test Statistic                   -1.520766
# p-value                           0.523215
# #Lags Used                       10.000000
# Number of Observations Used    2915.000000
# dtype: float64

# %%
fig = plt.figure(figsize = (8,4.5))
plt.plot(sber['CLOSE'].diff())
plt.xlabel('День')
plt.ylabel('Рублей')
plt.title('Первые разницы цены акции Сбербанка')
plt.show()

# %%
plot_acf_pacf(sber.dropna().diff().dropna(), 'первых разниц цен акций Сбербанка')

# %%
adftest = adfuller(sber.dropna().diff().dropna(), maxlag = 10, regression = 'c')

dfoutput = pd.Series(
        adftest[0:4],
        index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ]
)

dfoutput
# Out:
# Test Statistic                -1.813730e+01
# p-value                        2.496450e-30
# #Lags Used                     9.000000e+00
# Number of Observations Used    2.915000e+03
# dtype: float64

# %%
evaluation = pd.DataFrame(columns = ['lagAR', 'lagMA', 'aic', 'bic'])
row = 0
for i in range(0,5):
    for j in range(0,5):
        results = sm.tsa.arima.ARIMA(sber.dropna().diff().dropna(), order=(i, 0, j)).fit()
        evaluation.loc[row, ['lagAR', 'lagMA', 'aic', 'bic']] = [i, j, results.aic, results.bic]
        row += 1
# Out:
# C:\Anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
evaluation.sort_values(by = 'bic').head()
# Out:
#    lagAR lagMA           aic           bic
# 0      0     0  16437.288886  16449.250986
# 10     2     0  16431.588719  16455.512918
# 2      0     2  16432.416818  16456.341017
# 5      1     0   16439.28478  16457.227929
# 1      0     1  16439.285204  16457.228353

# %%
results = sm.tsa.arima.ARIMA(sber.dropna().diff().dropna(), order=(0, 0, 0), trend = 'n').fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  CLOSE   No. Observations:                 2925
# Model:                          ARIMA   Log Likelihood               -8216.858
# Date:                Thu, 05 Dec 2024   AIC                          16435.715
# Time:                        00:02:25   BIC                          16441.696
# Sample:                             0   HQIC                         16437.869
#                                - 2925
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        16.1269      0.076    212.227      0.000      15.978      16.276
# ...
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            441735.42
# Prob(Q):                              0.95   Prob(JB):                         0.00
# ...

# %%
sm.stats.acorr_ljungbox(results.resid, lags = 10, boxpierce= True)
# Out:
#       lb_stat  lb_pvalue    bp_stat  bp_pvalue
# 1    0.004106   0.948910   0.004101   0.948936
# 2    9.685185   0.007887   9.671951   0.007939
# 3    9.688251   0.021411   9.675011   0.021541
# 4   16.401100   0.002526  16.374100   0.002556
# 5   20.160888   0.001166  20.124896   0.001184
# 6   20.294864   0.002454  20.258506   0.002491
# 7   20.366829   0.004830  20.330250   0.004899
# 8   20.999050   0.007150  20.960311   0.007254
# 9   32.967224   0.000135  32.883507   0.000140
# 10  35.244152   0.000113  35.151100   0.000118

# %%
results = sm.tsa.arima.ARIMA(sber.dropna().diff().dropna(), order=(2, 0, 0), trend = 'n').fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  CLOSE   No. Observations:                 2925
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -8211.981
# Date:                Thu, 05 Dec 2024   AIC                          16429.962
# Time:                        23:31:03   BIC                          16447.906
# Sample:                             0   HQIC                         16436.425
#                                - 2925
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0013      0.011      0.117      0.907      -0.021       0.023
# ar.L2          0.0577      0.007      8.517      0.000       0.044       0.071
# sigma2        16.0731      0.132    121.599      0.000      15.814      16.332
# ...

# %%
sm.stats.acorr_ljungbox(results.resid, lags = 10, boxpierce= True)
# Out:
#       lb_stat  lb_pvalue    bp_stat  bp_pvalue
# 1    0.000119   0.991308   0.000119   0.991312
# 2    0.021453   0.989331   0.021424   0.989345
# 3    0.025833   0.998904   0.025796   0.998907
# 4    6.009468   0.198442   5.997165   0.199360
# 5    9.869336   0.079023   9.847802   0.079664
# 6   10.092216   0.120822  10.070073   0.121732
# 7   10.124322   0.181637  10.102080   0.182862
# 8   10.601965   0.225288  10.578092   0.226769
# 9   22.485934   0.007460  22.417399   0.007646
# 10  24.870373   0.005597  24.792063   0.005754

# %%
results = sm.tsa.arima.ARIMA(sber.dropna(), order=(2, 1, 0)).fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  CLOSE   No. Observations:                 2926
# Model:                 ARIMA(2, 1, 0)   Log Likelihood               -8211.981
# Date:                Thu, 05 Dec 2024   AIC                          16429.962
# Time:                        23:33:15   BIC                          16447.906
# Sample:                             0   HQIC                         16436.425
#                                - 2926
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0013      0.011      0.117      0.907      -0.021       0.023
# ar.L2          0.0577      0.007      8.517      0.000       0.044       0.071
# sigma2        16.0731      0.132    121.599      0.000      15.814      16.332
# ...

# %%
def r_squared(y_true, y_pred):
    return 1 - (np.sum((y_true - y_pred)**2)/np.sum((y_true - np.mean(y_true))**2))

def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred)**2))

def plot_forecast(y_train, y_test, y_forecast, trim = 300):
    T = len(y_train)
    horizon = len(y_test)
    fig = plt.figure(figsize = (8,4.5))
    plt.plot(range(trim, T), y_train[trim:], label = 'train')
    plt.xlabel('Период')
    plt.ylabel('Значение')
    plt.title(r'Тренинговая, тестовая выборки и прогноз')
    plt.plot(range(T, T + horizon), y_test, label = 'test')
    plt.plot(range(T, T + horizon), y_forecast, label = 'forecast')
    plt.legend()
    plt.show()

# %%
y_train = sber.iloc[:-10].values
y_test = sber.iloc[-10:].values

# %%
results = sm.tsa.arima.ARIMA(y_train, order=(0, 1, 0)).fit()
y_fcst = results.forecast(steps = 10)
plot_forecast(y_train, y_test, y_fcst, trim = 2500)
print('R-squared:', r_squared(y_test, y_fcst))
print('RMSE:', root_mean_squared_error(y_test, y_fcst))
print('MAPE:', mean_absolute_percentage_error(y_test, y_fcst))
# Out:
# R-squared: -53.75536375611576
# RMSE: 13.457807027892784
# MAPE: 4.789455307962109

# %%
results = sm.tsa.arima.ARIMA(y_train, order=(2, 1, 0)).fit()
y_fcst = results.forecast(steps = 10)
plot_forecast(y_train, y_test, y_fcst, trim = 2500)
print('R-squared:', r_squared(y_test, y_fcst))
print('RMSE:', root_mean_squared_error(y_test, y_fcst))
print('MAPE:', mean_absolute_percentage_error(y_test, y_fcst))
# Out:
# R-squared: -53.492700786624816
# RMSE: 13.425489491067502
# MAPE: 4.775224886316889
